# %%
import prosperity3bt
import pandas as pd
import itertools

from prosperity3bt.runner import run_backtest
from prosperity3bt.models import TradeMatchingMode
from prosperity3bt.file_reader import FileSystemReader
from pathlib import Path

from importlib import reload

# %%
import ink_trader
reload(ink_trader)

trader = ink_trader.Trader()
data_path = "."
round_num = 1
day = -2

backtest_results = prosperity3bt.runner.run_backtest(trader, file_reader=FileSystemReader(Path(data_path)), round_num=round_num, day_num=day, print_output=False, trade_matching_mode=TradeMatchingMode.all, no_names=True, show_progress_bar=False)

# %%
backtest_results.activity_logs[0].columns

rows = [row.columns for row in backtest_results.activity_logs]

columns = ['day', 'timestamp', 'product', 'bid_price_1', 'bid_volume_1',
       'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3',
       'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2',
       'ask_price_3', 'ask_volume_3', 'mid_price', 'profit_and_loss']

prices = pd.DataFrame(rows, columns=columns)

# %%
backtest_results.trades[0].trade.
# Out:
# (KELP,  << , 2002, 1, 0)

# %%
columns = ['timestamp', 'buyer', 'seller', 'symbol', 'currency', 'price', 'quantity']

rows = [(row.trade.timestamp, row.trade.buyer, row.trade.seller, row.trade.symbol, 'SEASHELLS', row.trade.price, row.trade.quantity) for row in backtest_results.trades]

trades = pd.DataFrame(rows, columns=columns)

# %%
prices
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -2          0              KELP         1998            26
# 1       -2          0  RAINFOREST_RESIN         9996             1
# 2       -2          0         SQUID_INK         1998            26
# 3       -2        100              KELP         2000             5
# 4       -2        100  RAINFOREST_RESIN        10000             5
# ...    ...        ...               ...          ...           ...
# 29995   -2     999800  RAINFOREST_RESIN         9996             1
# 29996   -2     999800         SQUID_INK         2002            26
# 29997   -2     999900              KELP         2027             4
# 29998   -2     999900  RAINFOREST_RESIN         9996             2
# 29999   -2     999900         SQUID_INK         2003             4
#
#       bid_price_2 bid_volume_2 bid_price_3 bid_volume_3  ask_price_1  \
# 0                                                               2002
# ...

# %%
trades
# Out:
#       timestamp buyer seller            symbol   currency  price  quantity
# 0             0                           KELP  SEASHELLS   2002         1
# 1             0               RAINFOREST_RESIN  SEASHELLS   9996         1
# 2             0               RAINFOREST_RESIN  SEASHELLS   9996         1
# 3             0                      SQUID_INK  SEASHELLS   2002         1
# 4           100                           KELP  SEASHELLS   2002         6
# ...         ...   ...    ...               ...        ...    ...       ...
# 8388     998900                           KELP  SEASHELLS   2029         1
# 8389     998900                      SQUID_INK  SEASHELLS   2001         1
# 8390     999000                           KELP  SEASHELLS   2030         9
# 8391     999000                      SQUID_INK  SEASHELLS   2002         9
# 8392     999800               RAINFOREST_RESIN  SEASHELLS   9998         1
#
# [8393 rows x 7 columns]
