# %%
import pandas as pd

# %%
prices = pd.read_csv('submissions/v0.csv', sep=';')

# %%
resin = prices[prices['product'] == 'RAINFOREST_RESIN']
ink = prices[prices['product'] == 'SQUID_INK']
kelp = prices[prices['product'] == 'KELP']

# %%
resin.tail()
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 2987    1      99500  RAINFOREST_RESIN         9995            20
# 2988    1      99600  RAINFOREST_RESIN         9995            28
# 2993    1      99700  RAINFOREST_RESIN         9995            26
# 2996    1      99800  RAINFOREST_RESIN         9996             1
# 2998    1      99900  RAINFOREST_RESIN         9998             6
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 2987          NaN           NaN          NaN           NaN         9998
# 2988          NaN           NaN          NaN           NaN        10005
# 2993          NaN           NaN          NaN           NaN        10005
# 2996       9995.0          25.0          NaN           NaN        10002
# 2998       9996.0           1.0       9995.0          27.0        10004
#
#       ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# ...

# %%
ink.tail()
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 2985    1      99500  SQUID_INK         1814            20          NaN
# 2990    1      99600  SQUID_INK         1815            28          NaN
# 2992    1      99700  SQUID_INK         1813            26          NaN
# 2995    1      99800  SQUID_INK         1814            26          NaN
# 2997    1      99900  SQUID_INK         1816            27          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 2985           NaN          NaN           NaN         1818            20
# 2990           NaN          NaN           NaN         1818            28
# 2992           NaN          NaN           NaN         1817            26
# 2995           NaN          NaN           NaN         1817            26
# 2997           NaN          NaN           NaN         1819            28
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
kelp.tail()
# Out:
#       day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 2986    1      99500    KELP         2034            20          NaN
# 2989    1      99600    KELP         2034            28          NaN
# 2991    1      99700    KELP         2034            26          NaN
# 2994    1      99800    KELP         2034            26          NaN
# 2999    1      99900    KELP         2034            27          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 2986           NaN          NaN           NaN         2038            20
# 2989           NaN          NaN           NaN         2038            28
# 2991           NaN          NaN           NaN         2038            26
# 2994           NaN          NaN           NaN         2038            26
# 2999           NaN          NaN           NaN         2038            28
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
from read_submission_log import read_submission_log

prices, trades, sandbox = read_submission_log('submissions/empty.log')

# %%
prices[['bid_price_1', 'bid_volume_1',
       'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3',
       'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2',
       'ask_price_3', 'ask_volume_3']] = prices[['bid_price_1', 'bid_volume_1',
       'bid_price_2', 'bid_volume_2', 'bid_price_3', 'bid_volume_3',
       'ask_price_1', 'ask_volume_1', 'ask_price_2', 'ask_volume_2',
       'ask_price_3', 'ask_volume_3']].astype('Int64')

# %%
prices
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       1          0         SQUID_INK         1834            23
# 1       1          0  RAINFOREST_RESIN         9998             9
# 2       1          0              KELP         2032            23
# 3       1        100              KELP         2034             1
# 4       1        100         SQUID_INK         1837             1
# ...   ...        ...               ...          ...           ...
# 2995    1      99800         SQUID_INK         1814            26
# 2996    1      99800  RAINFOREST_RESIN         9996             1
# 2997    1      99900         SQUID_INK         1816            27
# 2998    1      99900  RAINFOREST_RESIN         9998             6
# 2999    1      99900              KELP         2034            27
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0            <NA>          <NA>         <NA>          <NA>         1838
# ...

# %%
prices.to_csv('round1/prices_round_1_day_1.csv', sep=';', index=False)
trades.to_csv('round1/trades_round_1_day_1_nn.csv', sep=';', index=False)
