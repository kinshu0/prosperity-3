# %%
import pandas as pd
from backtester import read_trader_log, read_submission_log

# %%
prices, trades = read_trader_log('logs/empty_submission.log')

# %%
resin_prices = prices[prices['product'] == 'RAINFOREST_RESIN']
resin_trades = trades[trades['symbol'] == 'RAINFOREST_RESIN']

# %%
resin_prices[resin_prices['timestamp'].isin(resin_trades['timestamp'])]
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0      -1          0  RAINFOREST_RESIN        10002             1
# 23     -1       1100  RAINFOREST_RESIN         9996             2
# 35     -1       1700  RAINFOREST_RESIN         9996             2
# 36     -1       1800  RAINFOREST_RESIN        10002             1
# 41     -1       2000  RAINFOREST_RESIN         9996             2
# ...   ...        ...               ...          ...           ...
# 3978   -1     198900  RAINFOREST_RESIN        10002             1
# 3980   -1     199000  RAINFOREST_RESIN         9996             2
# 3988   -1     199400  RAINFOREST_RESIN         9996             1
# 3991   -1     199500  RAINFOREST_RESIN        10002             1
# 3993   -1     199600  RAINFOREST_RESIN         9996             1
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          9996.0           2.0       9995.0          29.0        10004
# ...

# %%
resin_trades
# Out:
#       timestamp buyer seller            symbol   currency  price  quantity
# 2             0               RAINFOREST_RESIN  SEASHELLS  10004         1
# 3          1100               RAINFOREST_RESIN  SEASHELLS   9996         2
# 5          1700               RAINFOREST_RESIN  SEASHELLS  10002         1
# 6          1800               RAINFOREST_RESIN  SEASHELLS  10002         1
# 8          2000               RAINFOREST_RESIN  SEASHELLS   9998         1
# ...         ...   ...    ...               ...        ...    ...       ...
# 1074     198900               RAINFOREST_RESIN  SEASHELLS  10002         1
# 1076     199000               RAINFOREST_RESIN  SEASHELLS   9996         2
# 1083     199400               RAINFOREST_RESIN  SEASHELLS  10004         1
# 1084     199500               RAINFOREST_RESIN  SEASHELLS  10002         1
# 1087     199600               RAINFOREST_RESIN  SEASHELLS  10002         2
#
# [481 rows x 7 columns]

# %%
algo_trades[algo_trades['symbol'] == 'RAINFOREST_RESIN']
# Out:
#       timestamp       buyer      seller            symbol   currency  price  \
# 0             0              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10002
# 1             0              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10003
# 4          1100  SUBMISSION              RAINFOREST_RESIN  SEASHELLS   9997
# 5          1200  SUBMISSION              RAINFOREST_RESIN  SEASHELLS   9998
# 6          1300              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10002
# ...         ...         ...         ...               ...        ...    ...
# 1438     199200              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10000
# 1440     199400              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10003
# 1445     199500              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10002
# 1446     199500                          RAINFOREST_RESIN  SEASHELLS  10002
# 1447     199600              SUBMISSION  RAINFOREST_RESIN  SEASHELLS  10002
#
#       quantity
# 0            1
# 1            1
# ...

# %%
resin_prices[resin_prices['bid_price_1'] > 10000]
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0      -1          0  RAINFOREST_RESIN        10002             1
# 27     -1       1300  RAINFOREST_RESIN        10002             1
# 36     -1       1800  RAINFOREST_RESIN        10002             1
# 74     -1       3700  RAINFOREST_RESIN        10002             1
# 146    -1       7300  RAINFOREST_RESIN        10002             1
# ...   ...        ...               ...          ...           ...
# 3915   -1     195700  RAINFOREST_RESIN        10002             1
# 3920   -1     196000  RAINFOREST_RESIN        10002             2
# 3948   -1     197400  RAINFOREST_RESIN        10002             1
# 3978   -1     198900  RAINFOREST_RESIN        10002             1
# 3991   -1     199500  RAINFOREST_RESIN        10002             1
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          9996.0           2.0       9995.0          29.0        10004
# ...

# %%
algo_trades = read_submission_log('backtests/trader_v2_make.log')[1]
