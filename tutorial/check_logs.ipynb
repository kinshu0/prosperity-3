# %%
from backtester import read_submission_log
import pandas as pd

# %%
jmerle = pd.read_csv('logs/jmerle.csv', sep=';')
resinj = jmerle[jmerle['product'] == 'RAINFOREST_RESIN']
kelpj = jmerle[jmerle['product'] == 'KELP']

# %%
resinj.tail()
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 3991   -1     199500  RAINFOREST_RESIN        10002             1
# 3993   -1     199600  RAINFOREST_RESIN         9996             1
# 3994   -1     199700  RAINFOREST_RESIN         9998             8
# 3996   -1     199800  RAINFOREST_RESIN         9995            21
# 3999   -1     199900  RAINFOREST_RESIN         9996             2
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 3991       9996.0           1.0       9995.0          22.0        10004
# 3993       9995.0          21.0          NaN           NaN        10002
# 3994       9996.0           2.0       9995.0          25.0        10004
# 3996          NaN           NaN          NaN           NaN        10002
# 3999       9995.0          30.0          NaN           NaN        10004
#
#       ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# ...

# %%
kelpj.tail()
# Out:
#       day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 3990   -1     199500    KELP         2020            23          NaN
# 3992   -1     199600    KELP         2020            22          NaN
# 3995   -1     199700    KELP         2020            27          NaN
# 3997   -1     199800    KELP         2020            21          NaN
# 3998   -1     199900    KELP         2020            32          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 3990           NaN          NaN           NaN         2024            23
# 3992           NaN          NaN           NaN         2023             1
# 3995           NaN          NaN           NaN         2023             2
# 3997           NaN          NaN           NaN         2023            21
# 3998           NaN          NaN           NaN         2022             7
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
h = pd.read_csv('logs/highestv2.csv', sep=';')
resinh = h[h['product'] == 'RAINFOREST_RESIN']
kelph = h[h['product'] == 'KELP']

# %%
resinh.tail()
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 3991   -1     199500  RAINFOREST_RESIN        10002             1
# 3993   -1     199600  RAINFOREST_RESIN         9996             1
# 3994   -1     199700  RAINFOREST_RESIN         9998             8
# 3996   -1     199800  RAINFOREST_RESIN         9995            21
# 3999   -1     199900  RAINFOREST_RESIN         9996             2
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 3991       9996.0           1.0       9995.0          22.0        10004
# 3993       9995.0          21.0          NaN           NaN        10002
# 3994       9996.0           2.0       9995.0          25.0        10004
# 3996          NaN           NaN          NaN           NaN        10002
# 3999       9995.0          30.0          NaN           NaN        10004
#
#       ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# ...

# %%
kelph.tail()
# Out:
#       day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 3990   -1     199500    KELP         2020            23          NaN
# 3992   -1     199600    KELP         2020            22          NaN
# 3995   -1     199700    KELP         2020            27          NaN
# 3997   -1     199800    KELP         2020            21          NaN
# 3998   -1     199900    KELP         2020            32          NaN
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 3990           NaN          NaN           NaN         2024            23
# 3992           NaN          NaN           NaN         2023             1
# 3995           NaN          NaN           NaN         2023             2
# 3997           NaN          NaN           NaN         2023            21
# 3998           NaN          NaN           NaN         2022             7
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...
