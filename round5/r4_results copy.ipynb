# %%
from read_submission_log import read_submission_log
from matplotlib import pyplot as plt
import pandas as pd

# %%
md, th, sandbox = read_submission_log('r4_results.log')

# %%
md = pd.read_csv('pp3.csv', sep=';')

# %%
# plt.figure(figsize=(12, 6))
# md.groupby('product')['profit_and_loss'].plot()
# plt.legend()
products_to_plot = md['product'].unique()
for i in range(0, len(products_to_plot), 3):
    plt.figure(figsize=(12, 6))
    for product in products_to_plot[i:i+3]:
        md[md['product'] == product]['profit_and_loss'].reset_index(drop=True).plot(label=product)
    plt.legend()
    plt.show()

# %%
sandbox
# Out:
#      sandboxLog                                          lambdaLog  timestamp
# 0                price dif -0.44018086888718244\nrock price 992...          0
# 1                price dif 0.04946543010919413\nrock price 9919...        100
# 2                price dif 0.04951502940457431\nrock price 9919...        200
# 3                price dif 0.04605957755666168\nrock price 9919...        300
# 4                price dif 0.035479622361890506\nrock price 991...        400
# ...         ...                                                ...        ...
# 9995             price dif 0.21650225639314158\nrock price 1010...     999500
# 9996             price dif 0.2166984837876953\nrock price 10106...     999600
# 9997             price dif -0.28320272256496537\nrock price 101...     999700
# 9998             price dif -0.28347711991955293\nrock price 101...     999800
# 9999             price dif 0.21652975333927316\nrock price 1010...     999900
#
# [10000 rows x 3 columns]

# %%
md
# Out:
#        day  timestamp                      product  bid_price_1  bid_volume_1  \
# 0        4          0                    SQUID_INK       1928.0          22.0
# 1        4          0                   CROISSANTS       4296.0         129.0
# 2        4          0                         JAMS       6446.0          92.0
# 3        4          0  VOLCANIC_ROCK_VOUCHER_10000         34.0          21.0
# 4        4          0                         KELP       2036.0          22.0
# ...    ...        ...                          ...          ...           ...
# 14995    4      99900   VOLCANIC_ROCK_VOUCHER_9500        416.0          17.0
# 14996    4      99900                         KELP       2032.0          35.0
# 14997    4      99900   VOLCANIC_ROCK_VOUCHER_9750        179.0          17.0
# 14998    4      99900               PICNIC_BASKET2      30157.0           4.0
# 14999    4      99900               PICNIC_BASKET1      58357.0           2.0
#
# ...
